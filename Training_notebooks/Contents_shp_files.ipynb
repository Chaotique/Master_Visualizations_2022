# %% [markdown]
# # Spain, different maps
#
# Downloaded from http://centrodedescargas.cnig.es/CentroDescargas/index.jsp > Mapas vectoriales y Bases Cartográficas y Topográficas:
#
#     BCN500
#     Description: Base Cartográfica Nacional a escala 1:500.000.
#     SGR: ETRS89. Coordenadas geográficas longitud y latitud.
#     Download entity: toda España y por capas temáticas.
#     Format: shapefile (.shp)

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import pprint

import os
 
# Get the list of all shp files in BCN500 directory
dir_list = [x for x in os.listdir("./BCN500/") if x[-4:]==".shp"]

dir_list
# Out:
# ['BCN500_0602L_CARRETERA_PPAL.shp',
#  'BCN500_0205S_BATIMETRIA.shp',
#  'BCN500_0802L_TopoLINKS.shp',
#  'BCN500_0301S_HIDROGRAFIA.shp',
#  'BCN500_0605P_EST_FFCC.shp',
#  'BCN500_0604L_FFCC.shp',
#  'BCN500_0102S_ESPACIO_NAT.shp',
#  'BCN500_0608P_FARO.shp',
#  'BCN500_0603L_CARRETERA_SECUN.shp',
#  'BCN500_0301L_HIDROGRAFIA.shp',
#  'BCN500_0207S_ISLA.shp',
#  'BCN500_1001P_VERT_GEODESICO.shp',
#  'BCN500_0101S_LIMITE_ADM.shp',
#  'BCN500_0103L_EV_ENCLAVE_PROV.shp',
#  'BCN500_0503L_PRESA.shp',
#  'BCN500_0202L_EV_SIERRA.shp',
#  'BCN500_0502P_LUGAR_INTERES.shp',
#  'BCN500_0802T_ETIQUETAC_point.shp',
#  'BCN500_0607P_PUERTO_MAR.shp',
#  'BCN500_0302L_EV_HID_MAR_COS.shp',
#  'BCN500_0207L_EV_ISLA.shp',
#  'BCN500_0601L_AUTOP_AUTOV.shp',
#  'BCN500_0606P_AEROP_AEROD.shp',
#  'BCN500_0501P_POBLACION.shp',
#  'BCN500_S_MASCARA_RELIEVE.shp',
#  'BCN500_0204L_EV_AREA_GEOGRAF.shp',
#  'BCN500_0501S_POBLACION.shp',
#  'BCN500_0203P_PICO_PUERTO.shp',
#  'BCN500_0206L_EV_ACC_COSTA.shp',
#  'BCN500_0802T_ETIQUETAP_point.shp']

# %%
ids = {x:x[7:-4] for x in dir_list}
ids
# Out:
# {'BCN500_0602L_CARRETERA_PPAL.shp': '0602L_CARRETERA_PPAL',
#  'BCN500_0205S_BATIMETRIA.shp': '0205S_BATIMETRIA',
#  'BCN500_0802L_TopoLINKS.shp': '0802L_TopoLINKS',
#  'BCN500_0301S_HIDROGRAFIA.shp': '0301S_HIDROGRAFIA',
#  'BCN500_0605P_EST_FFCC.shp': '0605P_EST_FFCC',
#  'BCN500_0604L_FFCC.shp': '0604L_FFCC',
#  'BCN500_0102S_ESPACIO_NAT.shp': '0102S_ESPACIO_NAT',
#  'BCN500_0608P_FARO.shp': '0608P_FARO',
#  'BCN500_0603L_CARRETERA_SECUN.shp': '0603L_CARRETERA_SECUN',
#  'BCN500_0301L_HIDROGRAFIA.shp': '0301L_HIDROGRAFIA',
#  'BCN500_0207S_ISLA.shp': '0207S_ISLA',
#  'BCN500_1001P_VERT_GEODESICO.shp': '1001P_VERT_GEODESICO',
#  'BCN500_0101S_LIMITE_ADM.shp': '0101S_LIMITE_ADM',
#  'BCN500_0103L_EV_ENCLAVE_PROV.shp': '0103L_EV_ENCLAVE_PROV',
#  'BCN500_0503L_PRESA.shp': '0503L_PRESA',
#  'BCN500_0202L_EV_SIERRA.shp': '0202L_EV_SIERRA',
#  'BCN500_0502P_LUGAR_INTERES.shp': '0502P_LUGAR_INTERES',
#  'BCN500_0802T_ETIQUETAC_point.shp': '0802T_ETIQUETAC_point',
#  'BCN500_0607P_PUERTO_MAR.shp': '0607P_PUERTO_MAR',
#  'BCN500_0302L_EV_HID_MAR_COS.shp': '0302L_EV_HID_MAR_COS',
#  'BCN500_0207L_EV_ISLA.shp': '0207L_EV_ISLA',
#  'BCN500_0601L_AUTOP_AUTOV.shp': '0601L_AUTOP_AUTOV',
#  'BCN500_0606P_AEROP_AEROD.shp': '0606P_AEROP_AEROD',
#  'BCN500_0501P_POBLACION.shp': '0501P_POBLACION',
#  'BCN500_S_MASCARA_RELIEVE.shp': 'S_MASCARA_RELIEVE',
#  'BCN500_0204L_EV_AREA_GEOGRAF.shp': '0204L_EV_AREA_GEOGRAF',
#  'BCN500_0501S_POBLACION.shp': '0501S_POBLACION',
#  'BCN500_0203P_PICO_PUERTO.shp': '0203P_PICO_PUERTO',
#  'BCN500_0206L_EV_ACC_COSTA.shp': '0206L_EV_ACC_COSTA',
#  'BCN500_0802T_ETIQUETAP_point.shp': '0802T_ETIQUETAP_point'}

# %%
spain = {}
for maps in dir_list:
    print(ids[maps])
    try: 
        spain[ids[maps]] = gpd.read_file("BCN500/"+maps, crs="EPSG:4326")
        display(spain[ids[maps]].head(3))
        
        f, ax = plt.subplots()
        spain[ids[maps]].plot(ax = ax)
        plt.show()
        plt.close()
    except:
        print("could not be plotted")
    print("\n\n\n\n")
# Out:
# 0602L_CARRETERA_PPAL
#       ID ID_CODIGO      FECHA_ALTA TIPO_0602 ETIQUETA  \
# 0  10084     0602L  20110530000000        01    N-634
# 1  10085     0602L  20110530000000        04   AS-110
# 2  10086     0602L  20110530000000        03     None
#
#                                             geometry
# 0  LINESTRING Z (-6.99508 43.53865 0.00000, -6.99...
# 1  LINESTRING Z (-5.83756 43.54025 0.00000, -5.83...
# 2  LINESTRING Z (-7.05067 43.54549 0.00000, -7.05...
# 0205S_BATIMETRIA
#    ID PROFUNDIDA      FECHA_ALTA  \
# 0   1    100-200  20150130131221
# 1   2    100-200  20150130131221
# 2   4    100-200  20150130131221
#
#                                             geometry
# 0  POLYGON Z ((4.78815 43.17582 0.00000, 4.78565 ...
# 1  POLYGON Z ((4.14555 43.18410 0.00000, 4.14569 ...
# 2  POLYGON Z ((-0.85488 35.79136 0.00000, -0.8585...
# 0802L_TopoLINKS
# could not be plotted
#
#
#
#
#
# 0301S_HIDROGRAFIA
#    ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0301            ETIQUETA  \
# 0   1     0301S   031302  20101102000000        09       Laguna Grande
# 1   2     0301S   031202  20101102000000        07                None
# 2   3     0301S   031202  20101102000000        07  Embalse de la Joya
#
#                                             geometry
# 0  POLYGON Z ((-3.55792 37.92934 0.00000, -3.5589...
# 1  POLYGON Z ((-7.12535 37.75087 0.00000, -7.1255...
# 2  POLYGON Z ((-7.02243 37.75162 0.00000, -7.0230...
# 0605P_EST_FFCC
#      ID ID_CODIGO      FECHA_ALTA TIPO_0605                      ETIQUETA  \
# 0  3267     0605P  20110523000000        01  Estación FF.CC. de Salamanca
# 1  3268     0605P  20110523000000        02                          None
# 2  3269     0605P  20110523000000        01                          None
#
#                               geometry
# 0  POINT Z (-5.69012 40.95322 0.00000)
# 1  POINT Z (-3.01299 40.90582 0.00000)
# 2  POINT Z (-3.10378 40.89544 0.00000)
# 0604L_FFCC
#      ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0604 ETIQUETA  \
# 0  5616     0604L     None  20110527000000        01     None
# 1  5617     0604L     None  20110527000000        01     None
# 2  5618     0604L     None  20110527000000        01     None
#
#                                             geometry
# 0  LINESTRING Z (-0.51706 43.88097 0.00000, -0.51...
# 1  LINESTRING Z (-0.41550 43.93202 0.00000, -0.42...
# 2  LINESTRING Z (-0.49491 43.88078 0.00000, -0.49...
# 0102S_ESPACIO_NAT
#    ID ID_CODIGO ID_TTOPO  FECHA_ALTA TIPO_0102  \
# 0   1     0102S   010202  2010-12-10        02
# 1   2     0102S   010201  2010-12-10        01
# 2   3     0102S   010201  2010-12-10        01
#
#                                  ETIQUETA SITECODE  \
# 0  Parque Natural del Cañón del Río Lobos     None
# 1            PARQUE NACIONAL DE CABAÑEROS     None
# 2        PARQUE NACIONAL DE SIERRA NEVADA     None
#
#                                             geometry
# 0  POLYGON Z ((-3.04997 41.71808 0.00000, -3.0571...
# 1  POLYGON Z ((-4.34233 39.28192 0.00000, -4.3732...
# 2  POLYGON Z ((-3.37640 36.91283 0.00000, -3.3800...
# 0608P_FARO
#    ID ID_CODIGO      FECHA_ALTA          ETIQUETA  \
# 0   1     0608P  20091228000000              None
# 1   2     0608P  20091228000000              None
# 2   3     0608P  20091228000000  Faro del Espigón
#
#                               geometry
# 0  POINT Z (-7.12801 37.21215 0.00000)
# 1  POINT Z (-6.81859 37.13031 0.00000)
# 2  POINT Z (-6.83273 37.10866 0.00000)
# 0603L_CARRETERA_SECUN
#       ID ID_CODIGO ETIQUETA TIPO_0603      FECHA_ALTA  \
# 0  48677     0603L     None        03  20110523000000
# 1  48678     0603L     None        03  20110523000000
# 2  48679     0603L     None        03  20110523000000
#
#                                             geometry
# 0  LINESTRING Z (-1.29646 43.96746 0.00000, -1.29...
# 1  LINESTRING Z (-1.30298 43.94752 0.00000, -1.30...
# 2  LINESTRING Z (-0.91295 43.95294 0.00000, -0.91...
# 0301L_HIDROGRAFIA
#    ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0301             ETIQUETA  \
# 0   1     0301L   031103  20101102000000        03              Río Sor
# 1   2     0301L   031103  20101102000000        03  Río Grande de Xubia
# 2   3     0301L   031104  20101102000000        04             Río Esva
#
#   REGIMEN                                           geometry
# 0      01  LINESTRING Z (-7.75923 43.49695 0.00000, -7.75...
# 1      01  LINESTRING Z (-7.92035 43.49762 0.00000, -7.92...
# 2      01  LINESTRING Z (-6.47223 43.55215 0.00000, -6.46...
# 0207S_ISLA
#    ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0207 ETIQUETA  \
# 0   1     0207S   022203  20101129000000        03     None
# 1   2     0207S   022203  20101129000000        03     None
# 2   3     0207S   022203  20101129000000        03     None
#
#                                             geometry
# 0  POLYGON Z ((-8.16678 43.40889 0.00000, -8.1670...
# 1  POLYGON Z ((-8.44790 43.38025 0.00000, -8.4486...
# 2  POLYGON Z ((-8.44997 43.37828 0.00000, -8.4506...
# 1001P_VERT_GEODESICO
#      ID ID_CODIGO      FECHA_ALTA  COTA TIPO_1001    ETIQUETA ID_TTOPO  \
# 0  1333     1001P  20100326000000  1148        01   Bitigarra   100102
# 1  1334     1001P  20100326000000   590        01   Las Mugas   100102
# 2  1335     1001P  20100326000000   748        01  Asomadilla   100102
#
#                               geometry
# 0  POINT Z (-2.38181 42.75745 0.00000)
# 1  POINT Z (-2.69132 42.53579 0.00000)
# 2  POINT Z (-1.64063 39.23916 0.00000)
# 0101S_LIMITE_ADM
#    ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0101               CCAA  \
# 0  66     0101S     None  20150803093226        05  SAHARA OCCIDENTAL
# 1   5     0101S     None  20100924000000        01  SAHARA OCCIDENTAL
# 2   6     0101S     None  20100924000000        01            ALGERIA
#
#             ETIQUETA                                           geometry
# 0         Berzosilla  POLYGON Z ((-4.00309 42.76336 0.00000, -4.0075...
# 1  SAHARA OCCIDENTAL  POLYGON Z ((-13.17496 27.66696 0.00000, -13.16...
# 2            ALGERIA  POLYGON Z ((-2.20538 35.08055 0.00000, -2.1993...
# 0103L_EV_ENCLAVE_PROV
#     ID ID_CODIGO ID_TTOPO      FECHA_ALTA                  CCAA    ETIQUETA  \
# 0  125     0103L   010102  20110413000000  COMUNITAT VALENCIANA  (VALENCIA)
# 1  128     0103L   010102  20110413000000       CASTILLA Y LEÓN    (BURGOS)
# 2  130     0103L   010102  20110413000000             CANTABRIA       (CAN)
#
#   NOMBRE                                           geometry
# 0   None  LINESTRING Z (-1.32678 40.03994 0.00000, -1.23...
# 1   None  LINESTRING Z (-2.74749 42.68209 0.00000, -2.67...
# 2   None  LINESTRING Z (-3.29238 43.24654 0.00000, -3.25...
# 0503L_PRESA
#    ID ID_CODIGO ID_TTOPO      FECHA_ALTA                             ETIQUETA  \
# 0   1     0503L     None  20091207000000          Urrunagako Urtegiaren Presa
# 1   2     0503L     None  20091207000000  Ullibarri Ganboako Urtegiaren Presa
# 2   3     0503L     None  20091207000000            Albiñako Urtegiaren Presa
#
#                                             geometry
# 0  LINESTRING Z (-2.65895 42.95707 0.00000, -2.65...
# 1  LINESTRING Z (-2.62129 42.92781 0.00000, -2.61...
# 2  LINESTRING Z (-2.63123 42.99230 0.00000, -2.63...
# 0202L_EV_SIERRA
#      ID ID_CODIGO ID_TTOPO TIPO_0202 FUENTE  CCAA ME500 LONGITUD ALTITUD_MA  \
# 0  1594     0202L   021104      None   None  None  None     None       None
# 1  1595     0202L   021104      None   None  None  None     None       None
# 2  1596     0202L   021104      None   None  None  None     None       None
#
#   OBSERV               ETIQUETA      FECHA_ALTA  \
# 0   None  Monte de la Esperanza  20110408000000
# 1   None         Macizo de Teno  20110408000000
# 2   None        Macizo de Anaga  20110408000000
#
#                                             geometry
# 0  LINESTRING Z (-16.47070 28.33812 0.00000, -16....
# 1  LINESTRING Z (-16.88912 28.34469 0.00000, -16....
# 2  LINESTRING Z (-16.30103 28.53407 0.00000, -16....
# 0502P_LUGAR_INTERES
#      ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0502  \
# 0  2222     0502P   052101  20110524000000        01
# 1  2223     0502P   052101  20110524000000        01
# 2  2284     0502P   052101  20110609000000        03
#
#                           ETIQUETA                             geometry
# 0          Monasterio de la Rábida  POINT Z (-6.92625 37.20761 0.00000)
# 1            Monasterio de Veruela  POINT Z (-1.69285 41.81221 0.00000)
# 2  Conjunto Dolménico de Antequera  POINT Z (-4.53554 37.03520 0.00000)
# 0802T_ETIQUETAC_point
#     ID  LABELID  WORDID                       LAYERNAME STATUS  LBZFID  \
# 0  843        1       1  BCNd500_0203P_PICO_PUERTO_JOIN  FIXED      89
# 1  851        9       1  BCNd500_0203P_PICO_PUERTO_JOIN  FIXED      81
# 2  855       13       1  BCNd500_0203P_PICO_PUERTO_JOIN  FIXED      77
#
#   ORIGLABEL LBZLABELTY  LBZLEVELID  LBZOBJECTI LBZTEXTOBJ LBZSYMBOL LBZKEYED  \
# 0      1433          1           1           1     NOMBRE         0        0
# 1       674          1           1           1     NOMBRE         0        0
# 2       609          1           1           1     NOMBRE         0        0
#
#    LBZCHARSPA FCLASSNAME LABELCLASS                               geometry
# 0         0.0     021204     021204    POINT Z (98.32797 -1.95852 0.00000)
# 1         0.0     021204     021204  POINT Z (-58.95239 -44.47464 0.00000)
# 2         0.0     021204     021204    POINT Z (49.83309 87.04021 0.00000)
# 0607P_PUERTO_MAR
#    ID ID_CODIGO      FECHA_ALTA ETIQUETA                             geometry
# 0   1     0607P  20091229000000     None  POINT Z (-8.74084 42.24505 0.00000)
# 1   2     0607P  20091229000000     None  POINT Z (-8.70712 42.40232 0.00000)
# 2   3     0607P  20091229000000     None  POINT Z (-8.78211 42.60470 0.00000)
# 0302L_EV_HID_MAR_COS
#     ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0302 FUENTE  \
# 0  611      None   032103  20110408000000      None   None
# 1  612      None   032101  20110408000000      None   None
# 2  613      None   032202  20110408000000      None   None
#
#                     ETIQUETA  \
# 0     ESTRECHO DE LA BOCAINA
# 1           OCÉANO ATLÁNTICO
# 2  Ensenada Piedra de la Sal
#
#                                             geometry
# 0  LINESTRING Z (-13.92523 28.77797 0.00000, -13....
# 1  LINESTRING Z (-17.34333 28.70935 0.00000, -14....
# 2  LINESTRING Z (-16.45504 28.11252 0.00000, -16....
# 0207L_EV_ISLA
#     ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0207 FUENTE  \
# 0  181     0207L   022203  20110408000000      None   None
# 1  182     0207L   022202  20110408000000      None   None
# 2  183     0207L   022202  20110408000000      None   None
#
#                ETIQUETA                                           geometry
# 0         Montaña Clara  LINESTRING Z (-13.62240 29.30400 0.00000, -13....
# 1             ALEGRANZA  LINESTRING Z (-13.59214 29.42327 0.00000, -13....
# 2  ARCHIPIÉLAGO CHINIJO  LINESTRING Z (-13.41451 29.35705 0.00000, -13....
# 0601L_AUTOP_AUTOV
#      ID ID_CODIGO      FECHA_ALTA TIPO_0601 ETIQUETA  \
# 0  6248     0601L  20110530000000        01     N-10
# 1  6249     0601L  20110530000000        07     None
# 2  6250     0601L  20110530000000        07     None
#
#                                             geometry
# 0  LINESTRING Z (-1.07501 43.97189 0.00000, -1.08...
# 1  LINESTRING Z (-0.55051 43.87755 0.00000, -0.55...
# 2  LINESTRING Z (-0.84069 43.82983 0.00000, -0.84...
# 0606P_AEROP_AEROD
#    ID ID_CODIGO      FECHA_ALTA TIPO_0606 ETIQUETA  \
# 0   1     0606P  20091223000000        01    AEROP
# 1   2     0606P  20091223000000        01    AEROP
# 2   3     0606P  20091223000000        01    AEROP
#
#                               geometry
# 0  POINT Z (-5.34510 36.15061 0.00000)
# 1  POINT Z (-4.49640 36.67687 0.00000)
# 2  POINT Z (-3.77822 37.17579 0.00000)
# 0501P_POBLACION
#    ID  ID_OLD ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0501 COD_INE  \
# 0   1   382.0     0501P   051204  20091026000000        04    None
# 1   2   383.0     0501P   051204  20100923000000        04    None
# 2   3   384.0     0501P   051204  20091026000000        04    None
#
#         ETIQUETA  POB_ENT_SI                             geometry
# 0  Tleta Tarhamt         NaN  POINT Z (-5.44901 35.80965 0.00000)
# 1         Martil         NaN  POINT Z (-5.28486 35.64490 0.00000)
# 2          Zinat         NaN  POINT Z (-5.37866 35.49974 0.00000)
# S_MASCARA_RELIEVE
#    GID ID TIPO   SUBTIPO              ETIQUETA  \
# 0    1  1   05  PORTUGAL  MáscaraInternacional
# 1    2  2   05  PORTUGAL  MáscaraInternacional
# 2    3  3   05  PORTUGAL  MáscaraInternacional
#
#                                             geometry
# 0  POLYGON Z ((-8.80207 41.69236 0.00000, -8.7759...
# 1  POLYGON Z ((-8.79698 41.50679 0.00000, -8.7933...
# 2  POLYGON Z ((-9.54250 39.48159 0.00000, -9.5426...
# 0204L_EV_AREA_GEOGRAF
#     ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0204  CCAA FUENTE ME500 OBSERV  \
# 0  331     0204L   021303  20110408000000      None  None   None  None   None
# 1  332     0204L   021303  20110408000000      None  None   None  None   None
# 2  333     0204L   021303  20110408000000      None  None   None  None   None
#
#                 ETIQUETA                                           geometry
# 0    PENÍNSULA DE JANDÍA  LINESTRING Z (-14.43711 28.07495 0.00000, -14....
# 1         CAMPO DE NÍJAR  LINESTRING Z (-2.29807 36.91822 0.00000, -2.14...
# 2  MARQUESADO DEL ZENETE  LINESTRING Z (-3.16444 37.14923 0.00000, -2.93...
# 0501S_POBLACION
#   ID_CODIGO ID_TTOPO      FECHA_ALTA      COD_INE POB_ENT_SI TIPO_0501  \
# 0     0501S   051202  20090602000000  23005000101      36734        04
# 1     0501S   051202  20090602000000  23010000101      18763        04
# 2     0501S   051202  20090602000000  23009000201      15519        04
#
#   ETIQUETA  ID                                           geometry
# 0  Andújar   1  POLYGON Z ((-4.07253 38.04735 0.00000, -4.0689...
# 1   Bailén   2  POLYGON Z ((-3.79205 38.09393 0.00000, -3.7866...
# 2    Baeza   3  POLYGON Z ((-3.47886 37.99909 0.00000, -3.4767...
# 0203P_PICO_PUERTO
#      ID ID_CODIGO      FECHA_ALTA TIPO_0203 ETIQUETA ID_TTOPO   COTA  \
# 0  6089     0203P  20110523000000        04      912   021204  912.0
# 1  6090     0203P  20110523000000        04      306   021204  306.0
# 2  6091     0203P  20110523000000        04      485   021204  485.0
#
#                               geometry
# 0  POINT Z (-6.81639 37.86892 0.00000)
# 1  POINT Z (-7.38584 37.69147 0.00000)
# 2  POINT Z (-7.08917 37.91768 0.00000)
# 0206L_EV_ACC_COSTA
#      ID ID_CODIGO ID_TTOPO      FECHA_ALTA TIPO_0206 FUENTE  \
# 0  2040      None   022102  20110408000000      None   None
# 1  2041      None   022102  20110408000000      None   None
# 2  2042      None   022101  20110408000000      None   None
#
#               ETIQUETA                                           geometry
# 0       Punta Vizcaíno  LINESTRING Z (-16.95061 28.29660 0.00000, -16....
# 1  Punta de la Bonanza  LINESTRING Z (-17.92297 27.72758 0.00000, -17....
# 2          PUNTA GORDA  LINESTRING Z (-18.06784 28.78200 0.00000, -18....
# 0802T_ETIQUETAP_point
#       ID  LABELID  WORDID                       LAYERNAME  STATUS  LBZFID  \
# 0  28374        1       1  BCNd500_0203P_PICO_PUERTO_JOIN  PLACED  1522.0
# 1  28375        2       1  BCNd500_0203P_PICO_PUERTO_JOIN  PLACED  1521.0
# 2  28376        3       1  BCNd500_0203P_PICO_PUERTO_JOIN  PLACED  1520.0
#
#   ORIGLABEL LBZLABELTY  LBZLEVELID  LBZOBJECTI LBZTEXTOBJ LBZSYMBOL LBZKEYED  \
# 0      1030          1           1           1     NOMBRE         0        0
# 1       514          1           1           1     NOMBRE         0        0
# 2       595          1           1           1     NOMBRE         0        0
#
#    LBZCHARSPA FCLASSNAME LABELCLASS  \
# 0         0.0     021204     021204
# 1         0.0     021204     021204
# 2         0.0     021204     021204
#
#                                      geometry
# 0   MULTIPOINT Z (89.81078 -47.44508 0.00000)
# 1  MULTIPOINT Z (-27.24353 -10.41558 0.00000)
# 2    MULTIPOINT Z (-6.69471 61.83489 0.00000)

# %% [markdown]
# - EV_... : Entidades virtuales lineales para el posicionamiento de
# - ETIQUETA... : Tabla con geometría texto que contiene los textos que provienen del etiquetado automático de toda la toponimia

# %% [markdown]
# # Catalunya, administrative division
#
# Download zip file from https://www.icgc.cat/ca/Descarregues/Cartografia-vectorial/Divisions-administratives and unzip it aside of this .ipynb into a folder named "divisions_administratius".

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import pprint

import os
 
# Get the list of all shp files in BCN500 directory
dir_list_cat = [x for x in os.listdir("./divisions_administratius/") if x[-4:]==".shp"]
# first number: resolution/ scale, second number: Date

dir_list_cat
# Out:
# ['divisions-administratives-v2r1-provincies-500000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-50000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-50000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-1000000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-250000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-5000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-1000000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-1000000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-1000000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-100000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-250000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-500000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-5000-20220801.shp',
#  'divisions-administratives-v2r1-caps-municipi-20220801.shp',
#  'divisions-administratives-v2r1-municipis-100000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-50000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-500000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-5000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-5000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-100000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-50000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-100000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-1000000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-250000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-50000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-250000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-100000-20220801.shp',
#  'divisions-administratives-v2r1-comarques-500000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-5000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-250000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-500000-20220801.shp']

# %%
# list only highest resolution
dir_list_cat = [x for x in os.listdir("./divisions_administratius/") if x[-21:]=="-1000000-20220801.shp"]
dir_list_cat
# Out:
# ['divisions-administratives-v2r1-comarques-1000000-20220801.shp',
#  'divisions-administratives-v2r1-vegueries-1000000-20220801.shp',
#  'divisions-administratives-v2r1-catalunya-1000000-20220801.shp',
#  'divisions-administratives-v2r1-provincies-1000000-20220801.shp',
#  'divisions-administratives-v2r1-municipis-1000000-20220801.shp']

# %%
ids = {x:x[31:-21] for x in dir_list_cat}
ids
# Out:
# {'divisions-administratives-v2r1-comarques-1000000-20220801.shp': 'comarques',
#  'divisions-administratives-v2r1-vegueries-1000000-20220801.shp': 'vegueries',
#  'divisions-administratives-v2r1-catalunya-1000000-20220801.shp': 'catalunya',
#  'divisions-administratives-v2r1-provincies-1000000-20220801.shp': 'provincies',
#  'divisions-administratives-v2r1-municipis-1000000-20220801.shp': 'municipis'}

# %%
cat_maps = {}
for maps in dir_list_cat:
    cat_maps[ids[maps]] = gpd.read_file("./divisions_administratius/"+maps, crs="EPSG:4326")
    print(ids[maps])
    display(cat_maps[ids[maps]].head())
    cat_maps[ids[maps]].plot()
    plt.show()
    print("\n\n\n\n")
# Out:
# comarques
#   CODICOMAR        NOMCOMAR                CAPCOMAR  AREAC5000  \
# 0        01        Alt Camp                   Valls   537.6317
# 1        02     Alt Empordà                Figueres  1356.6431
# 2        03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3        04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4        05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373020.449 4590188.741, 372482.744 4...
# 1  MULTIPOLYGON (((513760.140 4662388.220, 513758...
# 2  POLYGON ((386593.300 4595896.200, 388616.100 4...
# 3  MULTIPOLYGON (((360800.100 4649174.000, 360624...
# 4  POLYGON ((327485.124 4721105.796, 327436.728 4...
# vegueries
#   CODIVEGUE           NOMVEGUE   CAPVEGUE    AREAV5000  \
# 0        06        Alt Pirineu          *  5142.598106
# 1        01          Barcelona  Barcelona  2350.074284
# 2        04  Camp de Tarragona  Tarragona  2703.384680
# 3        07  Catalunya Central          *  5057.499443
# 4        02             Girona     Girona  5581.293163
#
#                                             geometry
# 0  MULTIPOLYGON (((360800.100 4649174.000, 360624...
# 1  MULTIPOLYGON (((430781.151 4576638.077, 430763...
# 2  MULTIPOLYGON (((335047.090 4547015.090, 335000...
# 3  MULTIPOLYGON (((371355.616 4611241.896, 371360...
# 4  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# catalunya
#       NOMCAT     CAPCAT   AREACA5000  \
# 0  Catalunya  Barcelona  32103.99495
#
#                                             geometry
# 0  MULTIPOLYGON (((300644.450 4494148.850, 300643...
# provincies
#   CODIPROV    NOMPROV    CAPPROV   AREAP5000  \
# 0       08  Barcelona  Barcelona   7730.4124
# 1       17     Girona     Girona   5902.2156
# 2       25     Lleida     Lleida  12165.6897
# 3       43  Tarragona  Tarragona   6305.6772
#
#                                             geometry
# 0  MULTIPOLYGON (((386888.695 4561204.584, 386881...
# 1  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 2  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 3  MULTIPOLYGON (((300644.450 4494148.850, 300643...
# municipis
#   CODIMUNI             NOMMUNI             CAPMUNI   AREAM5000 CODICOMAR  \
# 0   250019  Abella de la Conca  Abella de la Conca   77.970082        25
# 1   080018              Abrera              Abrera   19.978096        11
# 2   250024                Àger                Àger  160.202629        23
# 3   250030            Agramunt            Agramunt   79.359535        38
# 4   080023  Aguilar de Segarra  Aguilar de Segarra   43.219825        07
#
#          NOMCOMAR                 CAPCOMAR CODIVEGUE           NOMVEGUE  \
# 0   Pallars Jussà                    Tremp        06        Alt Pirineu
# 1  Baix Llobregat  Sant Feliu de Llobregat        01          Barcelona
# 2         Noguera                 Balaguer        03             Lleida
# 3          Urgell                  Tàrrega        03             Lleida
# 4           Bages                  Manresa        07  Catalunya Central
#
#     CAPVEGUE CODIPROV    NOMPROV    CAPPROV  \
# 0          *       25     Lleida     Lleida
# 1  Barcelona       08  Barcelona  Barcelona
# 2     Lleida       25     Lleida     Lleida
# 3     Lleida       25     Lleida     Lleida
# 4          *       08  Barcelona  Barcelona
#
#                                             geometry
# 0  POLYGON ((346712.091 4676851.376, 347046.795 4...
# 1  POLYGON ((410315.500 4598888.500, 410888.800 4...
# 2  POLYGON ((308157.549 4660767.518, 308220.898 4...
# 3  MULTIPOLYGON (((342659.900 4635474.900, 343006...
# 4  POLYGON ((385155.746 4625034.736, 385288.746 4...

# %%
cat_maps["comarques"]
# Out:
#    CODICOMAR           NOMCOMAR                 CAPCOMAR  AREAC5000  \
# 0         01           Alt Camp                    Valls   537.6317
# 1         02        Alt Empordà                 Figueres  1356.6431
# 2         03        Alt Penedès   Vilafranca del Penedès   592.5498
# 3         04         Alt Urgell          la Seu d'Urgell  1447.2028
# 4         05     Alta Ribagorça         el Pont de Suert   427.2234
# 5         06              Anoia                 Igualada   867.0471
# 6         07              Bages                  Manresa  1092.7982
# 7         08          Baix Camp                     Reus   696.4883
# 8         09          Baix Ebre                  Tortosa  1001.9306
# 9         10       Baix Empordà      la Bisbal d'Empordà   701.1353
# 10        11     Baix Llobregat  Sant Feliu de Llobregat   487.4743
# 11        12       Baix Penedès              el Vendrell   296.4311
# 12        13         Barcelonès                Barcelona   146.3935
# 13        14           Berguedà                    Berga  1185.2257
# 14        15           Cerdanya                Puigcerdà   546.4545
# 15        16   Conca de Barberà                Montblanc   650.6021
# 16        17             Garraf     Vilanova i la Geltrú   185.2434
# 17        18          Garrigues      les Borges Blanques   797.2156
# 18        19           Garrotxa                     Olot   733.3229
# 19        20            Gironès                   Girona   575.9353
# 20        21            Maresme                   Mataró   397.9019
# 21        22            Montsià                  Amposta   733.6485
# 22        23            Noguera                 Balaguer  1783.3727
# 23        24              Osona                      Vic  1246.9802
# 24        25      Pallars Jussà                    Tremp  1343.5020
# 25        26     Pallars Sobirà                     Sort  1378.2154
# 26        27       Pla d'Urgell               Mollerussa   305.4285
# 27        28    Pla de l'Estany                 Banyoles   263.3198
# 28        29            Priorat                   Falset   498.0777
# 29        30      Ribera d'Ebre              Móra d'Ebre   827.6182
# 30        31           Ripollès                   Ripoll   956.8939
# 31        32            Segarra                  Cervera   723.5756
# 32        33             Segrià                   Lleida  1396.1161
# 33        34              Selva  Santa Coloma de Farners   994.0428
# 34        35           Solsonès                  Solsona  1000.2169
# 35        36         Tarragonès                Tarragona   320.5849
# 36        37         Terra Alta                  Gandesa   742.6641
# 37        38             Urgell                  Tàrrega   578.2949
# 38        39         Val d'Aran                   Vielha   632.9978
# 39        40  Vallès Occidental      Sabadell / Terrassa   583.0649
# 40        41    Vallès Oriental               Granollers   735.2397
# 41        42            Moianès                     Moià   337.2896
#
#                                              geometry
# 0   POLYGON ((373020.449 4590188.741, 372482.744 4...
# 1   MULTIPOLYGON (((513760.140 4662388.220, 513758...
# 2   POLYGON ((386593.300 4595896.200, 388616.100 4...
# 3   MULTIPOLYGON (((360800.100 4649174.000, 360624...
# 4   POLYGON ((327485.124 4721105.796, 327436.728 4...
# 5   POLYGON ((371426.378 4628557.172, 372106.708 4...
# 6   POLYGON ((417259.067 4646530.811, 417513.903 4...
# 7   MULTIPOLYGON (((335047.090 4547015.090, 335000...
# 8   MULTIPOLYGON (((311847.200 4514855.880, 311833...
# 9   MULTIPOLYGON (((498479.410 4622829.390, 498478...
# 10  POLYGON ((402255.460 4605174.574, 402529.150 4...
# 11  MULTIPOLYGON (((385851.064 4574022.148, 385800...
# 12  MULTIPOLYGON (((430781.151 4576638.077, 430763...
# 13  MULTIPOLYGON (((391614.800 4661923.500, 391606...
# 14  MULTIPOLYGON (((418012.433 4699884.940, 416441...
# 15  POLYGON ((369548.800 4603947.800, 370045.800 4...
# 16  MULTIPOLYGON (((386888.695 4561204.584, 386881...
# 17  POLYGON ((327888.707 4605730.867, 328155.807 4...
# 18  POLYGON ((462293.700 4686958.700, 462409.651 4...
# 19  POLYGON ((494081.526 4662565.750, 494214.685 4...
# 20  POLYGON ((477054.900 4621435.100, 478728.500 4...
# 21  MULTIPOLYGON (((300644.450 4494148.850, 300643...
# 22  POLYGON ((348524.976 4664596.302, 348224.932 4...
# 23  MULTIPOLYGON (((418580.652 4643167.275, 418307...
# 24  MULTIPOLYGON (((317718.105 4693389.714, 317738...
# 25  POLYGON ((343204.997 4738566.787, 343217.247 4...
# 26  MULTIPOLYGON (((341924.700 4618515.800, 341260...
# 27  POLYGON ((482350.600 4671869.500, 483369.000 4...
# 28  POLYGON ((320525.200 4579659.500, 321213.700 4...
# 29  POLYGON ((290923.800 4573932.800, 291056.392 4...
# 30  MULTIPOLYGON (((419785.996 4664417.149, 419923...
# 31  POLYGON ((366335.500 4642586.300, 367288.769 4...
# 32  MULTIPOLYGON (((315175.836 4605775.825, 315121...
# 33  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 34  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 35  POLYGON ((362512.057 4568174.143, 363125.922 4...
# 36  POLYGON ((280206.273 4568311.294, 280325.826 4...
# 37  MULTIPOLYGON (((330423.400 4623950.100, 329861...
# 38  POLYGON ((314392.071 4747419.593, 314795.594 4...
# 39  POLYGON ((426549.300 4618464.000, 427202.000 4...
# 40  POLYGON ((448722.100 4628732.200, 449076.876 4...
# 41  POLYGON ((428837.859 4639478.022, 428961.755 4...
